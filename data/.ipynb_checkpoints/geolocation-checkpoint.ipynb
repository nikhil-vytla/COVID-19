# %%
"""
Python script for batch geocoding of addresses using the Google Geocoding API.
This script allows for massive lists of addresses to be geocoded for free by pausing when the 
geocoder hits the free rate limit set by Google (2500 per day).  If you have an API key for paid
geocoding from Google, set it in the API key section.

Addresses for geocoding can be specified in a list of strings "addresses". In this script, addresses
come from a csv file with a column "Address". After every 500 successful geocode operations, a temporary file with results is recorded in case of 
script failure / loss of connection later.

Addresses and data are held in memory, so this script may need to be adjusted to process files line
by line if you are processing millions of entries.
"""

import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AI.....................................'
API_KEY = 'AIzaSyArm9gVOzsmXXsUZNmCxULgF6em1lAnNHY'
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = 'geotesting/Filtered_Geo04282020.csv'
# Set your input file here
input_filename = 'geotesting/FilteredDatabase04282020.csv'
# Specify the column name in your input data that contains addresses here
address_column_name = "Affiliation"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = pd.read_csv(input_filename, encoding='ISO-8859-1')

if address_column_name not in data.columns:
	raise ValueError("Missing Affiliation column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=API_KEY, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} affiliations".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all affiliations")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Pharmacy Services; Mercy Health Saint Mary's; Grand Rapids MI USA: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Centro de Estudos Sociais Amilcar Cabral  CESAC: INVALID_REQUEST
# Geocoded: Centro de Estudos Sociais Amilcar Cabral  CESAC: INVALID_REQUEST
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Advanced Biomedical Sciences, Federico II University of Naples, Naples, Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Royal United Hospitals Bath NHS Foundation Trust Bath UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Faculty of Health Sciences, Simon Fraser University; Burnaby, British Columbia, Canada: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Head &amp; Neck ServiceMemorial Sloan Kettering Cancer Center New York New York USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Institut Mutualiste Montsouris, Paris, France: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Medicine and Surgery, University of Salerno, Baronissi, Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: First Department of Cardiology, Medical University of Warsaw, Waraw, Poland: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Surgery, University of Massachusetts Medical School-Baystate Medical Center, Springfield, Massachusetts, USA.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: The Global Centre for Mass Gatherings Medicine, Ministry of Health, Riyadh, Saudi Arabia: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Institute of Hygiene, University Hospital Münster, Münster, Germany: OK
# Geocoded: Department of Pathology, Medical College of Georgia, Augusta University, Augusta, GA, USA (Dr. Schwartz); Amareen Dhaliwal, BS, Boston University School of Medicine, Boston, MA, USA (Ms. Dhaliwal): OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Department of Environmental and Biological Sciences, University of Eastern Finland, Yliopistonranta 1, 70210, Kuopio, Finland;: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Woman and Child Health and Public Health Fondazione Policlinico Universitario A. Gemelli IRCCS Università Cattolica del Sacro Cuore Rome Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Internal Medicine Division of Nephrology Leiden University Medical Center Leiden The Netherlands: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Public Policy, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599, USA.: OK
# Geocoded: Section of Dermatology, Department of Clinical Medicine and SurgeryUniversity of Naples Federico II Naples Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Medicine, Tallaght University Hospital & Trinity College Dublin, Ireland: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Cellular and Molecular Signaling New York, New York 10022, United States: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Completed 100 of 10203 affiliations
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Basic Medical Sciences, Neuroscience and Sensory Organs, University of Bari, School of Medicine, Bari, Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Biological Sciences Middle East Technical University Ankara Turkey: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Western Norway Research Institute, Sogndal, Norway;: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: NCH Physician Group, Center for Healthy Living, 132 Moorings Park Drive, Naples, FL, USA: OK
# Geocoded: Robert F. Wagner Graduate School of Public Service, New York University, New York, New York: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Clinical Biochemistry, University of Westminster, London, UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: National and Kapodistrian University of Athens, Athens, Greece: OK
# Geocoded: From the Department of Biostatistics, University of Florida, Gainesville (N.E.D., I.M.L.); the World Health Organization, Geneva (P.-S.G., A.M.H.-R.); the Department of Biostatistics, University of California, Los Angeles (R.B.); the Department of Biostatistics, Yale University, New Haven, CT (F.W.C.); the Department of Statistics (C.A.D.) and the Centre for Tropical Medicine and Global Health (P.H.), University of Oxford, Oxford, the Medical Research Council (MRC) Centre for Global Infectious Disease...: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Queen Alexandra Hospital Portsmouth UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Dermatology Department Paris University, Saint?Louis Hospital Paris France: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Infectious Diseases, Cleveland Clinic, Cleveland, Ohio: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of Medicine and Surgery, University of Milano Bicocca, Monza, Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Communication, Cornell University, Ithaca, NY: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: LSU Health Shreveport, LA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Institute for Research, Quality, and Policy in Homeless Health Care, Boston Health Care for the Homeless Program, Boston, Massachusetts: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Cardiology, West China Hospital, Sichuan University, 37 Guoxue Alley, Chengdu, 610041, PR China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding H. Holden Thorp Editor-in-Chief, Science journals.: ZERO_RESULTS
# Geocoded: H. Holden Thorp Editor-in-Chief, Science journals.: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Laboratory of Molecular Immunopharmacology and Drug Discovery, Department of ImmunologyTufts University School of Medicine Boston MA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Infectious Diseases Unit, Department of Medical and Surgical Sciences, Policlinico di SantOrsola, Bologna, Italy: INVALID_REQUEST
# Geocoded: Infectious Diseases Unit, Department of Medical and Surgical Sciences, Policlinico di SantOrsola, Bologna, Italy: INVALID_REQUEST
# Geocoded: Dermatology Unit Department of Experimental, Diagnostic and Specialty Medicine University of Bologna: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Applied NanoFemto Technologies, LLC, Lowell, MA 01851, USA: OK
# Geocoded: Duke University Trinity College, Durham, NC, USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Geocoded: Harvard Radiation Oncology Program, Boston, MA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Associate Professor, History, Quaid-i-Azam University, Islamabad, Pakistan: OK
# Geocoded: Joshua Sokol is a journalist in Boston.: OK
# Geocoded: Department of Occupational & Environmental Health, School of Public Health, Tongji Medical College, Huazhong University of Science and Technology, Wuhan, Hubei, China: OK
# Geocoded: Trade Researcher, Shridath Ramphal Centre, The University of the West Indies Cave Hill: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Completed 200 of 10203 affiliations
# Geocoded: Process Safety Services Punta Gorda Florida USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Biological Resource Center, Taizhou Hospital of Zhejiang Province, Taizhou Enze Medical Center (Group), Linhai, Zhejiang, China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Pediatric Intensive Care Unit, Nursing Department, West China Second University Hospital of Sichuan University, Chengdu, Sichuan, China (mainland): OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Faculty of Health Sciences, Simon Fraser University, Burnaby, BC: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of MedicineUniversidad de Sonora Mexico: OK
# Geocoded: Brain Research Institute, University of Zurich, Zurich, Switzerland.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Medical Genome Sciences, Research Institute for Frontier Medicine: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Renal Medicine Singapore General Hospital Singapore Singapore: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Cardiology, General Hospital of Northern Theater Command, 83 Wenhua Road, 110840 Shenyang, China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Helwan University Medical biochemistry and molecular biology Cairo Egypt: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Department of Obstetrics and Gynecology Fondazione IRCCS Ca Granda Ospedale Maggiore Policlinico Milan Italy: INVALID_REQUEST
# Geocoded: Department of Obstetrics and Gynecology Fondazione IRCCS Ca Granda Ospedale Maggiore Policlinico Milan Italy: INVALID_REQUEST
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Biophysics Department, Faculty of Sciences, Cairo University, Giza, Egypt.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Kristen R. Choi, PhD, MS, RN, University of California, Los Angeles, CA, USA: OK
# Geocoded: University of Hong Kong Ringgold standard institution ? Schoo of Nursing Hong Kong Hong Kong: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Professor of Clinical Pediatrics, State University of New York at Stony Brook, Stony Brook, New York.: OK
# Geocoded: UOC Dermatologia ASST Papa Giovanni XXIII Bergamo Hospital LombardyBergamo Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Completed 300 of 10203 affiliations
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Xavier Institute of Social Service, Ranchi, India;: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Preventive Medicine College of Medicine University of Tennessee Health Science Center: OK
# Geocoded: Scientific Department Wellcomet GmbH Karlsruhe Germany: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: University of Cologne Medical Faculty University Hospital Cologne Department I of Internal Medicine 50937 Cologne Germany: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Division of Nephrology Department of Internal Medicine Keimyung University School of Medicine Daegu Korea: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of MedicineUniversity of LiverpoolLiverpool United Kingdom: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Qatar University Biomedical Research Center, Qatar: OK
# Error geocoding State Key Laboratory of Veterinary Biotechnology, Harbin Veterinary Research Institute of Chinese Academy of Agricultural Sciences, Harbin, Peoples Republic of China: INVALID_REQUEST
# Geocoded: State Key Laboratory of Veterinary Biotechnology, Harbin Veterinary Research Institute of Chinese Academy of Agricultural Sciences, Harbin, Peoples Republic of China: INVALID_REQUEST
# Geocoded: Key Laboratory for Biodiversity and Ecological Engineering of Ministry of Education, College of Life Sciences, Beijing Normal University, Beijing 100875, China.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Mass Communication Newhouse School of Public Communication at Syracuse University NY USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Department of OtolaryngologyHead and Neck SurgeryMedical University of South Carolina Charleston South Carolina USA: INVALID_REQUEST
# Geocoded: Department of OtolaryngologyHead and Neck SurgeryMedical University of South Carolina Charleston South Carolina USA: INVALID_REQUEST
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Department of OtolaryngologyHead and Neck SurgeryUniversity of Toronto Toronto Ontario Canada: INVALID_REQUEST
# Geocoded: Department of OtolaryngologyHead and Neck SurgeryUniversity of Toronto Toronto Ontario Canada: INVALID_REQUEST
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Jeffrey Sachs Center on Sustainable Development, Sunway University, Bandar Sunway, Malaysia: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Comprehensive Headache Program Department of Neurology Wake Forest Baptist Health Winston?Salem NC USA: OK
# Geocoded: Department of PsychologyWesleyan University Middletown Connecticut USA: OK
# Geocoded: Respiratory Health Division, National Institute for Occupational Safety and Health, US Centers for Disease Control and Prevention, Morgantown, West Virginia: OK
# Geocoded: Department of Cardiology, West China Hospital, Sichuan University, 37 Guoxue Alley, Chengdu, 610041, PR China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Ausvet Europe Lyon 69001 France: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Departments of Gastrointestinal Surgery; Wuhan China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Dipartimento Scienze della Salute della Donna, del Bambino e di Sanità Pubblica, Fondazione Policlinico Universitario Agostino Gemelli, IRCCS, Roma Italia: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Infectious Diseases, Zoohygiene and Veterinary Sanitary Inspection of Federal State Budget Educational Institution of Higher Education "Bashkir State Agrarian University", Ufa 450001, Republic Bashkortostan, Russian Federation.: OK
# Geocoded: Department of General Surgery; St Mary's Hospital, Isle of Wight NHS Trust; Newport UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Oxford Brookes University Faculty of Health and Life Sciences Oxford Institute of Nursing, Midwifery, and Allied Health Research (OxINMAHR) Headington Campus, the Colonnade 2.13 OX3 0BP Oxford Oxfordshire UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Skin Diseases and Leishmaniasis Research CenterIsfahan University of Medical Sciences Isfahan Iran: OK
# Geocoded: Department of Pediatrics, Division of NeurologyUniversity of Arkansas for Medical Sciences Little Rock AR USA: OK
# Geocoded: 1 Természettudományi Kutatóközpont, Enzimológiai Intézet, Magyar Tudományos AkadémiaBudapest: OK
# Geocoded: Dermatology Department Ambroise Paré University Hospital Center Boulevard Kennedy, 2 B7000 Mons Belgium: OK
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding Author Not Found: ZERO_RESULTS
# Geocoded: Author Not Found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of Social and Political Sciences, University of Melbourne, Melbourne, Australia: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Completed 400 of 10203 affiliations
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: College of Animal Science and Veterinary Medicine, Henan Agricultural University, Zhengzhou 450002, China.: OK
# Geocoded: State Key Laboratory of Veterinary Biotechnology, Harbin Veterinary Research Institute, Chinese Academy of Agricultural Sciences, Harbin, China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of Government, Beijing Normal University, Beijing 100875, China.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Karl Landsteiner University of Health Sciences, Department of Opthalmology, Dunant Platz 1, 3100 St Poelten, Austria: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Internal Medicine, Radboud University Medical Center, Nijmegen, Netherlands: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Maxillofacial Surgery UnitUniversity Hospital of Sassari Viale San Pietro 43/B Sassari 07100 Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: University of Geneva, Switzerland: OK
# Geocoded: Department of Rheumatology, The First Affiliated Hospital of Nanjing Medical University, Nanjing, China.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Echocardiography Department, Royal Brompton and Harefield Foundation Trust, Harefield Hospital, London, UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Health Sciences, University of Arkansas Libraries, Fayetteville, Arkansas, USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Department of Head and Neck OncologyTata Memorial Center and HBNI Mumbai India: OK
# Geocoded: Department of Head and Neck OncologyTata Memorial Center Mumbai India: OK
# Geocoded: Virology Sector, Laboratory of Immunopathology Keizo Asami, Federal University of Pernambuco, Pernambuco, Brazil.: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Rockcourt Medical Centre, Blackrock, Dublin, Ireland and President of the European Society of Contraception and Reproductive Health;: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of OtolaryngologyUniversity of Pittsburgh Medical Center Pittsburgh Pennsylvania USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Clinical Laboratory, The Third People's Hospital of Shenzhen, Southern University of Science and Technology, National Clinical Research Center for Infectious Diseases, Shenzhen, China: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: 1Department of Neurology Landesklinikum Mistelbach?Gänserndorf Mistelbach Austria: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# ...
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Australian National University Canberra ACT: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Department of Surgical Sciences, B-Researcher and Professor of Plastic and Reconstructive Surgery, University of Rome Tor Vergata School of Medicine, Rome, 00173, Italy.: INVALID_REQUEST
# Geocoded: Department of Surgical Sciences, B-Researcher and Professor of Plastic and Reconstructive Surgery, University of Rome Tor Vergata School of Medicine, Rome, 00173, Italy.: INVALID_REQUEST
# Geocoded: Dermatology Department of Medical and Surgical Sciences Università Cattolica del Sacro Cuore Rome Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: From Massachusetts General Hospital and Harvard Medical School, Boston (R.T.G.); the Department of Medicine, Division of Allergy and Infectious Diseases, University of Washington School of Medicine, Seattle (J.B.L.); and the Department of Medicine, Division of Infectious Diseases, Emory University School of Medicine, and Grady Health System, Atlanta (C.R.).: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: From the Department of Medicine, University of California, San Francisco.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Cardiac SurgeryBristol Heart Institute Bristol UK: OK
# Geocoded: 1 Általános Orvostudományi Kar, Klinikai Központ, Aneszteziológiai és Intenzív Terápiás Klinika, Debreceni EgyetemDebrecen, Nagyerdei krt. 98., 4032: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Oxford Suzhou Centre for Advanced Research (OSCAR) University of Oxford Suzhou Industrial Park Jiangsu China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Integrated Medical Science Charles E. Schmidt College of Medicine Florida Atlantic University Boca Raton FL USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of Nursing, West China Hospital; Sichuan University; Chengdu Sichuan P. R. China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Departments of AnesthesiologyMedicine and Physiology, David Geffen School of Medicine at UCLA USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: School of Computer ScienceInstitute for Research in Fundamental Sciences Tehran Iran: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: North?West University, Unit for Environmental Sciences and Management South Africa: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: The Department of Ophthalmology First Affiliated Hospital School of Medicine Zhejiang University Hangzhou China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Center for Bioethics and Social Science in Medicine, Institute for Healthcare Policy and Innovation: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Centre Hospitalier Universitaire Félix Guyon, Pneumologie, Allée des Topazes, 97400, Saint Denis, France: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Journalism and Media Studies Centre, The University of Hong Kong, Hong Kong: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Irish Centre for Vascular Biology School of Pharmacy and Biomolecular Sciences Royal College of Surgeons in Ireland Dubli Ireland: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Dermatology Department Henri Mondor hospital Créteil France: OK
# Geocoded: Dermatology Department Henri Mondor hospital Créteil France: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding EUPHA Deputy Director: ZERO_RESULTS
# Geocoded: EUPHA Deputy Director: ZERO_RESULTS
# Geocoded: Orthodontic Department, Unicoc, Cali, Colombia.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of OtolaryngologyUniversity of Pittsburgh Medical Center Pittsburgh Pennsylvania USA: OK
# Geocoded: Keck School of Medicine, University of Southern California, Los Angeles, CA: OK
# Geocoded: Lecturer at the University of Management and Technology: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Completed 1100 of 10203 affiliations
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Purdue University College of Pharmacy; Carmel Indiana: OK
# Geocoded: John Radcliffe Hospital Oxford UK: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Pediatrics, University of Florida, Gainesville: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Psychology, Sociology and PoliticsSheffield Hallam University Sheffield UK: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Universität StuttgartInstitut für Organische Chemie Pfaffenwaldring 55 70569 Stuttgart GERMANY: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: 1NeurosurgeryOne, Denver, Colorado;: OK
# Geocoded: 1NeurosurgeryOne, Denver, Colorado;: OK
# Geocoded: Univ. Lille, Inserm U1285, CHU Lille, Pôle de Réanimation, CNRS, UMR 8576 - UGSF -Unité de Glycobiologie Structurale et Fonctionnelle, F-59000, Lille, France: OK
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Geocoded: Dermatology Unit University of Campania Luigi Vanvitelli Naples Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding New YorkPresbyterian Weill Cornell Medical Center, New York, NY: INVALID_REQUEST
# Geocoded: New YorkPresbyterian Weill Cornell Medical Center, New York, NY: INVALID_REQUEST
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Medicine Division of Infectious Disease Columbia University College of Physicians &amp; Surgeons New York NY United States: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Infectious DiseasesThird Affiliated Hospital of Sun Yat?sen University Guangzhou 510630 Guangdong China: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Editor in Chief, British Journal of Nursing: ZERO_RESULTS
# Geocoded: Editor in Chief, British Journal of Nursing: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Neil Pearce is with the London School of Hygiene and Tropical Medicine (LSHTM), London, UK. Jan P. Vandenbroucke is with the Leiden University Medical Center, Leiden, Netherlands, Aarhus University, Aarhus, Denmark, and the LSHTM. Tyler J. VanderWeele is with the Harvard T.?H. Chan School of Public Health, Boston, MA. Sander Greenland is with the Departments of Epidemiology and Statistics, University of California, Los Angeles.: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: West Virginia University Morgantown West Virginia USA: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Clinical Science and Translational Medicine University of Rome Tor Vergata Rome Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding Response not 200: ZERO_RESULTS
# Geocoded: Response not 200: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: UOC Chirurgia Generale, Ospedale Valtiberina - Sansepolcro, Usl Toscana Sud-Est; Italy: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: University of Manchester, Manchester, UK: OK
# Geocoded: State Key Laboratory of Drug Research, CAS Key Laboratory of Receptor Research, Shanghai Institute of Materia Medica, Chinese Academy of Sciences, Shanghai 201203, China.: OK
# Geocoded: Universidade Federal do Mato Grosso do Sul,  Brasil; Fundação Oswaldo Cruz,  Brasil; Ministério da Saúde,  Brasil: OK
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Geocoded: Department of Dermatology and VenereologyUniversity of Trieste, Ospedale Maggiore Trieste Italy: OK
# Geocoded: Division of Infectious Diseases I, Fondazione IRCCS Policlinico San Matteo, Pavia, Italy: OK
# Error geocoding Laboratory of Clinical Informatics and Cardiovascular Imaging: ZERO_RESULTS
# Geocoded: Laboratory of Clinical Informatics and Cardiovascular Imaging: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
# Error geocoding No affiliation found: ZERO_RESULTS
# Geocoded: No affiliation found: ZERO_RESULTS
